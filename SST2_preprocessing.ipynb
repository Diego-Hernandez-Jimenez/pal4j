# %%
! pip install -U datasets -q

# %%
from transformers import pipeline
from datasets import load_dataset
import numpy as np
import pandas as pd

# %%
ds = load_dataset("stanfordnlp/sst2")

# %%
feature_extractor = pipeline("feature-extraction", model='distilbert-base-uncased')

extracted_features = []
labels = []
for instance in ds["train"]:
    features = feature_extractor(instance["sentence"], return_tensors="pt")[0]
    # pool the features
    reduced_features = features.numpy().mean(axis=0)
    extracted_features.append(reduced_features)
    labels.append(instance["label"])

features_df = pd.DataFrame(extracted_features)
labels_series = pd.Series(labels, name='label')
combined_df = pd.concat([features_df, labels_series], axis=1)

combined_df.columns = [f"x{i}" for i in range(combined_df.shape[1] - 1)] + ['label']
combined_df["label"] = combined_df["label"].apply(lambda x: -1 if x == 0 else 1) # change label
combined_df

print("DataFrame created with features and labels:")
combined_df.head()
# Out:
# Device set to use cuda:0
# DataFrame created with features and labels:
#           0         1         2         3         4         5         6  \
# 0  0.114925 -0.074180 -0.103861  0.161894  0.271635 -0.168071  0.220195
# 1 -0.000710  0.106148 -0.046511  0.211409  0.035901 -0.194607 -0.144562
# 2 -0.056553  0.089973 -0.065338  0.115917  0.302289 -0.119069  0.076227
# 3  0.376848 -0.033898  0.261397 -0.182839  0.266461 -0.135566  0.251487
# 4  0.072887  0.228848 -0.047050  0.139485 -0.151458 -0.064155  0.115758
#
#           7         8         9  ...       759       760       761       762  \
# 0  0.072963  0.069062 -0.094296  ...  0.103204  0.014921 -0.025962  0.051029
# 1  0.447088  0.086273 -0.162743  ...  0.155330 -0.203959 -0.047006  0.029578
# 2  0.612448  0.041701 -0.256289  ... -0.080381  0.000972 -0.066015 -0.159979
# 3  0.256586  0.029199 -0.285730  ...  0.133094  0.341499 -0.096782  0.237338
# 4  0.307542  0.259947  0.138878  ... -0.042041  0.044563 -0.097860 -0.262329
#
#         763       764       765       766       767  label
# 0 -0.109610 -0.088453 -0.009364 -0.105031  0.249623      0
# 1 -0.286936  0.138253 -0.235586  0.229131 -0.035826      0
# 2 -0.089037  0.411418 -0.330658  0.286063 -0.057917      1
# 3 -0.500887  0.062045 -0.144268  0.088031  0.037056      0
# 4 -0.146962 -0.028682 -0.119395  0.481294 -0.210109      0
#
# [5 rows x 769 columns]

# %%
combined_df.columns = [f"x{i}" for i in range(combined_df.shape[1] - 1)] + ['label']
combined_df["label"] = combined_df["label"].apply(lambda x: -1 if x == 0 else 1)
combined_df
# Out:
#              x0        x1        x2        x3        x4        x5        x6  \
# 0      0.114925 -0.074180 -0.103861  0.161894  0.271635 -0.168071  0.220195
# 1     -0.000710  0.106148 -0.046511  0.211409  0.035901 -0.194607 -0.144562
# 2     -0.056553  0.089973 -0.065338  0.115917  0.302289 -0.119069  0.076227
# 3      0.376848 -0.033898  0.261397 -0.182839  0.266461 -0.135566  0.251487
# 4      0.072887  0.228848 -0.047050  0.139485 -0.151458 -0.064155  0.115758
# ...         ...       ...       ...       ...       ...       ...       ...
# 67344 -0.043436  0.135832 -0.066078 -0.121258  0.001117 -0.244640  0.275053
# 67345  0.031801  0.443866 -0.037034 -0.020101 -0.043648  0.148495  0.025094
# 67346 -0.116226  0.101447  0.136684 -0.015374 -0.041740 -0.048571  0.240074
# 67347  0.085971 -0.070157 -0.030378 -0.016145  0.146016  0.034397  0.235033
# 67348  0.105348  0.092290  0.303893  0.072113  0.020674 -0.159287  0.122389
#
#              x7        x8        x9  ...      x759      x760      x761  \
# 0      0.072963  0.069062 -0.094296  ...  0.103204  0.014921 -0.025962
# 1      0.447088  0.086273 -0.162743  ...  0.155330 -0.203959 -0.047006
# 2      0.612448  0.041701 -0.256289  ... -0.080381  0.000972 -0.066015
# 3      0.256586  0.029199 -0.285730  ...  0.133094  0.341499 -0.096782
# 4      0.307542  0.259947  0.138878  ... -0.042041  0.044563 -0.097860
# ...         ...       ...       ...  ...       ...       ...       ...
# 67344  0.191455 -0.146763  0.028469  ... -0.178413 -0.172401 -0.179340
# 67345  0.175371 -0.089454 -0.427973  ...  0.045811 -0.010740 -0.212189
# 67346  0.387545 -0.020798 -0.337476  ...  0.033415  0.138999 -0.078592
# 67347 -0.022201  0.204930 -0.134076  ... -0.059069 -0.093016 -0.341004
# 67348  0.325269 -0.124797 -0.257061  ...  0.232543  0.247654 -0.189745
#
#            x762      x763      x764      x765      x766      x767  label
# 0      0.051029 -0.109610 -0.088453 -0.009364 -0.105031  0.249623     -1
# 1      0.029578 -0.286936  0.138253 -0.235586  0.229131 -0.035826     -1
# 2     -0.159979 -0.089037  0.411418 -0.330658  0.286063 -0.057917      1
# 3      0.237338 -0.500887  0.062045 -0.144268  0.088031  0.037056     -1
# 4     -0.262329 -0.146962 -0.028682 -0.119395  0.481294 -0.210109     -1
# ...         ...       ...       ...       ...       ...       ...    ...
# 67344  0.064031 -0.241927  0.146464 -0.114866  0.154454  0.164532      1
# 67345 -0.118657 -0.427046  0.057084 -0.293467  0.231825 -0.152285     -1
# 67346  0.020891 -0.153230  0.237456 -0.385342  0.163619  0.089755      1
# 67347 -0.172876  0.025765 -0.052752 -0.134591 -0.038293  0.100329      1
# 67348  0.005696 -0.257714  0.071212 -0.235795  0.102775 -0.313561     -1
#
# [67349 rows x 769 columns]

# %%
combined_df.to_csv("sst2_features_training_dataset.csv", index=False)

# %%
extracted_features = []
labels = []
for instance in ds["validation"]:
    features = feature_extractor(instance["sentence"], return_tensors="pt")[0]
    # pool the features
    reduced_features = features.numpy().mean(axis=0)
    extracted_features.append(reduced_features)
    labels.append(instance["label"])

features_df = pd.DataFrame(extracted_features)
labels_series = pd.Series(labels, name='label')
combined_df = pd.concat([features_df, labels_series], axis=1)

combined_df.columns = [f"x{i}" for i in range(combined_df.shape[1] - 1)] + ['label']
combined_df["label"] = combined_df["label"].apply(lambda x: -1 if x == 0 else 1) # change label
